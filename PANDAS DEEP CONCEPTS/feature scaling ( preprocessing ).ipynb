# %% [markdown]
# PERFORMING NORMALIZATION [ MIN - MAX SCALING]

# %%
import pandas as pd
data = pd.read_csv('Titanic-Dataset.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#sklearn.preprocessing is the library that contains the function minmaxscaler
from sklearn.preprocessing import MinMaxScaler

# minmaxscaler function transforms data values to specific range (default is between 0 and 1)
scaling = MinMaxScaler()
#fit_transform function fits the age column to the range , knows the max and min values and sets accordingly
data[['Age','Fare']] = scaling.fit_transform(data[['Age','Fare']])
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male  0.271174
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.472229
# 2                               Heikkinen, Miss. Laina  female  0.321438
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.434531
# 4                             Allen, Mr. William Henry    male  0.434531
# ..                                                 ...     ...       ...
# ...

# %% [markdown]
# FEATURE SCALING USING STANDARDIZATION [ Z-SCORE NORMALIZATION ] TECHNIQUE ( AVOIDS OUTLIERS ALSO )

# %%
import pandas as pd
data1 = pd.read_csv('Titanic-Dataset.csv')

# %%
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()
#SCALES VALUES WITH MEAN 0 AND STD 1
data1[['Age','Fare']] = scale.fit_transform(data1[['Age','Fare']])
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male -0.530377
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.571831
# 2                               Heikkinen, Miss. Laina  female -0.254825
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.365167
# 4                             Allen, Mr. William Henry    male  0.365167
# ..                                                 ...     ...       ...
# ...

# %% [markdown]
# FEATURE SCALING WITH MAX ABS SCALING, RHOBUST SCALING

# %%
import pandas as pd
data2 = pd.read_csv('Titanic-Dataset.csv')

# %%
from sklearn.preprocessing import MaxAbsScaler 
scaler = MaxAbsScaler()
#SCALES VALUS WITH -1 TO 1 IF DATA CONTAINS BOTH +VE AND -VE , 0 TO 1 IF DATA ONLY  +VE ,0 TO -1 IF DATA ONLY  -VE
data2[['Age','Fare']] = scaler.fit_transform(data2[['Age','Fare']])
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex     Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  0.2750      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.4750      1
# 2                               Heikkinen, Miss. Laina  female  0.3250      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.4375      1
# 4                             Allen, Mr. William Henry    male  0.4375      0
# ...

# %%
data2.to_csv('Titanic-MaxAbs feature scaling.csv')

# %%
import pandas as pd
data3 = pd.read_csv('Titanic-Dataset.csv')

# %%
from sklearn.preprocessing import RobustScaler 
scaler1 = RobustScaler()
# removes median and scales with IQR
data3[['Age','Fare']] = scaler1.fit_transform(data3[['Age','Fare']])
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male -0.335664
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.559441
# 2                               Heikkinen, Miss. Laina  female -0.111888
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.391608
# 4                             Allen, Mr. William Henry    male  0.391608
# ..                                                 ...     ...       ...
# ...
